# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/alvarogutyerrez/alvarogutyerrez/blob/master/S03_data_handle.ipynb)

# %% [markdown]
# # Business Intelligence para las Finanzas
# **Magister en Finanzas**
#
# **Profesor: David Díaz **
#
# **Autor: Álvaro Gutiérrez**
#
# ---
#
# #Sesión #3:  Pandas 2.0 (_concat_ and _group_by_)
#
#
# En esta sesión aprendermos lo básico sobre el manejo de bases de datos. Por ejemplo, cocatenar distintas bases de datos mediante [append](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.append.html) y [concat](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.concat.html). Una vez hecho esto, haremos uso de group_by para trabajar con alguna submuestra de la data que cumpla con ciertas caracteristicas.

# %% [markdown]
# ##Importando data a ocupar.
#
# Se cargará un archivo excel que posee las 4 bases a utilizar en esta sesión. El archivo se cargará al ambiente Collaborative mediante el comando _!wget_ más el link de dropbox donde se encuentra almacenado. Adicionalmente, (posiblemente) necesitemos instalar la librería xlrd, la cual es la encargada de manejar archivos excel desde pandas. Esto se hará mediante el comando _!pip install xlrd_

# %%
# !wget https://www.dropbox.com/s/3ch8lgbq65nu8fw/data_base_to_work_with.xlsx
# !pip install xlrd
# Out:
# Redirecting output to ‘wget-log.10’.
# Requirement already satisfied: xlrd in /usr/local/lib/python2.7/dist-packages (1.1.0)

# %% [markdown]
# Este archivo contiene 4 hojas:
#
#
# 1.   **merge_firms**: Lista de firmas latinoamericanas con sus respectivos ratios financieros (EBIT, CAPEX, DEBT...). Información correspondiente al año 2014.
# 2.  **merge_firms_to_add**: Ratios adicionales de las mismas firmas listadas anteriormente, también corresponde a 2014.
# 3.  **merge_countries** : Información relacionada a ciertos países de la muestra (Tasa de inflacion, tasa impositiva, población total), también corresponde a 2014.
# 4. **append_2013**: Simil de la información de **merge_firms**, pero para año 2013.

# %%
import pandas as pd #Importando pandas
excel_file = 'data_base_to_work_with.xlsx' #Importando el archivo excel recién cargado mediante !wget
#Primera hoja del libro excel "merge_firms"
merge_firms = pd.read_excel(excel_file, sheetname='merge_firms')
merge_firms.head(3)
# Out:
#          id           CompanyCommonName    country  TRBCEconomicSectorName  \
# 0  ABEV3.SA                    Ambev SA     Brazil  Consumer Non-Cyclicals
# 1     AC.MX  Arca Continental SAB de CV     Mexico  Consumer Non-Cyclicals
# 2    AGR.BA               Agrometal SAI  Argentina             Industrials
#
#   TRBCBusinessSectorName                                          industry  \
# 0       Food & Beverages                                         Beverages
# 1       Food & Beverages                                         Beverages
# 2       Industrial Goods  Machinery, Tools, Heavy Vehicles, Trains & Ships
#
#    time          capx  book_value_per_share         csho    ...      \
# 0  2014 -1.691000e+09              1.013250  15710000000    ...
# 1  2014 -3.119000e+08              1.939020   1611000000    ...
# 2  2014 -3.360144e+05              0.285851     48000000    ...
#
#             at          dlt  dltt         dp  rd  dividend        stock  \
# 0  27150000000  607700000.0   NaN        NaN NaN       NaN  15700000000
# 1   5448000000  954800000.0   NaN        NaN NaN   0.07634   1610000000
# 2     27977816    3212402.5   NaN  41093.885 NaN       NaN     48000000
#
#    equity_share_holder   debtcap        age
# 0          15900000000  0.058483  12.150580
# 1           3120000000  0.255116   6.272416
# 2             13700000  0.335568  59.373030
#
# [3 rows x 21 columns]

# %% [markdown]
# inspeccionando las dimesiones del objeto creado

# %%
merge_firms.shape
# Out:
# (191, 21)

# %% [markdown]
# ##[Concat](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.concat.html):
#
# ###Preproceso: set_index
#
# Lo primero que realizaremos será pegar la segunda hoja del libro excel (**merge_firms_to_add**) con la base que acabamos de importar (**merge_firms**) haciendo ocupando como "llave" en el pegado a la columna **id**. Pero para esto necesitamos realizar un preproceso con el índice e incluir dicha columna como indice de nuestro DataFrame. Al activar la opción **inplace = True**,  permite sobre escribir el DataFrame modificado en el mismo que ya teníamos. En caso de activar False, entonces creará uno nuevo. Finalmente, activamos la opción **drop =True**, para no tener duplicado el index como variable también..  Luego repetimos el mismo procedimiento para la base a concatenar.

# %%
merge_firms.set_index('id', inplace=True, drop =True)#Reemplaza el indice por la informaciona contenida en la columna "id"
merge_firms.head(3)
# Out:
#                    CompanyCommonName    country  TRBCEconomicSectorName  \
# id
# ABEV3.SA                    Ambev SA     Brazil  Consumer Non-Cyclicals
# AC.MX     Arca Continental SAB de CV     Mexico  Consumer Non-Cyclicals
# AGR.BA                 Agrometal SAI  Argentina             Industrials
#
#          TRBCBusinessSectorName  \
# id
# ABEV3.SA       Food & Beverages
# AC.MX          Food & Beverages
# AGR.BA         Industrial Goods
#
#                                                   industry  time  \
# id
# ABEV3.SA                                         Beverages  2014
# AC.MX                                            Beverages  2014
# AGR.BA    Machinery, Tools, Heavy Vehicles, Trains & Ships  2014
#
#                   capx  book_value_per_share         csho       deb_tot  \
# id
# ABEV3.SA -1.691000e+09              1.013250  15710000000  9.871000e+08
# AC.MX    -3.119000e+08              1.939020   1611000000  1.070000e+09
# AGR.BA   -3.360144e+05              0.285851     48000000  6.929635e+06
#
#                    at          dlt  dltt         dp  rd  dividend  \
# id
# ABEV3.SA  27150000000  607700000.0   NaN        NaN NaN       NaN
# AC.MX      5448000000  954800000.0   NaN        NaN NaN   0.07634
# AGR.BA       27977816    3212402.5   NaN  41093.885 NaN       NaN
#
#                 stock  equity_share_holder   debtcap        age
# id
# ABEV3.SA  15700000000          15900000000  0.058483  12.150580
# AC.MX      1610000000           3120000000  0.255116   6.272416
# AGR.BA       48000000             13700000  0.335568  59.373030

# %% [markdown]
# ah

# %%
merge_firms.shape #Confirmamos que perdemos una columna del DataFrame
# Out:
# (191, 20)

# %% [markdown]
# **...Repitiendo para el segundo dataframe**

# %%
merge_firms_to_add = pd.read_excel(excel_file, sheetname='merge_firms_to_add')
merge_firms_to_add.set_index('id', inplace=True , drop =True) #Reemplaza el indice por la informaciona contenida en la columna "id"
merge_firms_to_add.head(5)
# Out:
#           total_equity          ebit  total_liability       revenue      size
# id
# ABEV3.SA  1.589000e+10  6.016000e+09     1.126000e+10  1.433000e+10  23.38575
# AC.MX     3.124000e+09  7.315000e+08     2.324000e+09  4.202000e+09  22.15887
# AGR.BA    1.372086e+07  4.457442e+06     1.425696e+07  3.141261e+07  17.26272
# AGU.SN    1.643000e+08  2.735000e+07     4.171000e+08  6.122000e+08  20.23258
# AGUAa.SN  1.007000e+09  3.419000e+08     1.642000e+09  7.268000e+08  20.40417

# %%
merge_firms_to_add.shape
# Out:
# (191, 5)

# %% [markdown]
# ##Concat: Pegado usando index como "llave"
#
# Ahora podemos realizar el pegado de ambos dataframes en uno nuevo. Esto se realizará con los siguientes argumentos para la función concat.
# 1.  Elementos a concatenar [nuestros dos data frame separados por una coma ]
# 2.  Axis: 1 es un pegado ocupando como llave el index (nuestro caso). Un cero es ocupando el nombre de las columanas como llave (a desarrollar más adelante)
# 3.  El indice de pegado, en este caso nos servirá cualquiera de los dos DataFrame ya que posee exactamente el mismo index (mismo número de observaciones.)

# %%
merged_data_2014 = pd.concat([merge_firms, merge_firms_to_add], axis=1, join_axes=[merge_firms_to_add.index])
merged_data_2014.shape
# Out:
# (191, 25)

# %% [markdown]
# ## Concat: Pegado usando una columna como "llave"
#
# Ahora cargaremos la base **merge_countries** y adicionaremos esa información a la base recién creada (**merged_data_2014**).**merge_countries** como mencionamos anteriormente, contiene información a un nivel de agregación diferente al de las dos bases anteriores. Las bases anteriores tenían un nivel de agregación "micro", es decir podíamos identificar a cada una de las firmas. Ahora la información corresponde a una agregación a nivel "macro", ya que es información a nivel país. Esto último, implica que las filas de la base **merge_countries**, serán asignadas a más de una de las filas de la base **merged_data_2014**, debido a que por ejemplo, la inflación de Chile (que es una fila de **merge_countries**) será asignada a todas las firmas que estén ubicadas en Chile.

# %%
#Cargando base merge_countries
merge_countries = pd.read_excel(excel_file,sheetname="merge_countries")
print(merge_countries)
# Out:
#      country  inflation  tax_rate  population
# 0  Argentina   0.947232  0.254727    43132000
# 1     Brazil   0.052223  0.398399   204519000
# 2      Chile   0.974318  0.248184    18006000
# 3   Colombia   0.945748  0.255085    48218000
# 4     Mexico   0.185648  0.392126   121006000

# %% [markdown]
# ### Pegado "one to many" (como NO hacerlo....)

# %% [markdown]
# #### Primera forma de hacerlo MAL. No especificar el _axis_ del pegado.

# %%
merged_data_2014_countries_wrong1 =  pd.concat([merged_data_2014, merge_countries] , axis=1 )
merged_data_2014_countries_wrong1.head(8)
# Out:
#                    CompanyCommonName    country  TRBCEconomicSectorName  \
# 0                                NaN        NaN                     NaN
# 1                                NaN        NaN                     NaN
# 2                                NaN        NaN                     NaN
# 3                                NaN        NaN                     NaN
# 4                                NaN        NaN                     NaN
# ABEV3.SA                    Ambev SA     Brazil  Consumer Non-Cyclicals
# AC.MX     Arca Continental SAB de CV     Mexico  Consumer Non-Cyclicals
# AGR.BA                 Agrometal SAI  Argentina             Industrials
#
#          TRBCBusinessSectorName  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ABEV3.SA       Food & Beverages
# AC.MX          Food & Beverages
# AGR.BA         Industrial Goods
#
#                                                   industry    time  \
# 0                                                      NaN     NaN
# 1                                                      NaN     NaN
# 2                                                      NaN     NaN
# 3                                                      NaN     NaN
# 4                                                      NaN     NaN
# ABEV3.SA                                         Beverages  2014.0
# AC.MX                                            Beverages  2014.0
# AGR.BA    Machinery, Tools, Heavy Vehicles, Trains & Ships  2014.0
#
#                   capx  book_value_per_share          csho       deb_tot  \
# 0                  NaN                   NaN           NaN           NaN
# 1                  NaN                   NaN           NaN           NaN
# 2                  NaN                   NaN           NaN           NaN
# 3                  NaN                   NaN           NaN           NaN
# 4                  NaN                   NaN           NaN           NaN
# ABEV3.SA -1.691000e+09              1.013250  1.571000e+10  9.871000e+08
# AC.MX    -3.119000e+08              1.939020  1.611000e+09  1.070000e+09
# AGR.BA   -3.360144e+05              0.285851  4.800000e+07  6.929635e+06
#
#              ...             age  total_equity          ebit  total_liability  \
# 0            ...             NaN           NaN           NaN              NaN
# 1            ...             NaN           NaN           NaN              NaN
# 2            ...             NaN           NaN           NaN              NaN
# 3            ...             NaN           NaN           NaN              NaN
# 4            ...             NaN           NaN           NaN              NaN
# ABEV3.SA     ...       12.150580  1.589000e+10  6.016000e+09     1.126000e+10
# AC.MX        ...        6.272416  3.124000e+09  7.315000e+08     2.324000e+09
# AGR.BA       ...       59.373030  1.372086e+07  4.457442e+06     1.425696e+07
#
#                revenue      size    country  inflation  tax_rate   population
# 0                  NaN       NaN  Argentina   0.947232  0.254727   43132000.0
# 1                  NaN       NaN     Brazil   0.052223  0.398399  204519000.0
# 2                  NaN       NaN      Chile   0.974318  0.248184   18006000.0
# 3                  NaN       NaN   Colombia   0.945748  0.255085   48218000.0
# 4                  NaN       NaN     Mexico   0.185648  0.392126  121006000.0
# ABEV3.SA  1.433000e+10  23.38575        NaN        NaN       NaN          NaN
# AC.MX     4.202000e+09  22.15887        NaN        NaN       NaN          NaN
# AGR.BA    3.141261e+07  17.26272        NaN        NaN       NaN          NaN
#
# [8 rows x 29 columns]

# %% [markdown]
# #### Segunda forma de hacerlo MAL: Creer que Python es más inteligente que tu.
#
# Si ocupamos el mismo delimitador de axis que ocupamos antes, entonces python encontrará cero coincidencias ya que nuestra nueva variable posee un index que va del cero al cuatro, lo que no tiene coincidencia, obtiendo algo horrible como lo que sigue.

# %%
merged_data_2014_countries_wrong2 =  pd.concat([merged_data_2014, merge_countries] , axis=1 ,join_axes=[merge_firms_to_add.index] )
merged_data_2014_countries_wrong2.head(8)
# Out:
#                    CompanyCommonName    country  TRBCEconomicSectorName  \
# id
# ABEV3.SA                    Ambev SA     Brazil  Consumer Non-Cyclicals
# AC.MX     Arca Continental SAB de CV     Mexico  Consumer Non-Cyclicals
# AGR.BA                 Agrometal SAI  Argentina             Industrials
# AGU.SN       Agencias Universales SA      Chile             Industrials
# AGUAa.SN            Aguas Andinas SA      Chile               Utilities
# ALFAA.MX              Alfa SAB de CV     Mexico             Industrials
# ALI.LM                   Alicorp SAA       Peru  Consumer Non-Cyclicals
# ALPA4.SA               Alpargatas SA     Brazil      Consumer Cyclicals
#
#               TRBCBusinessSectorName  \
# id
# ABEV3.SA            Food & Beverages
# AC.MX               Food & Beverages
# AGR.BA              Industrial Goods
# AGU.SN                Transportation
# AGUAa.SN                   Utilities
# ALFAA.MX    Industrial Conglomerates
# ALI.LM              Food & Beverages
# ALPA4.SA  Cyclical Consumer Products
#
#                                                   industry  time  \
# id
# ABEV3.SA                                         Beverages  2014
# AC.MX                                            Beverages  2014
# AGR.BA    Machinery, Tools, Heavy Vehicles, Trains & Ships  2014
# AGU.SN                        Freight & Logistics Services  2014
# AGUAa.SN                         Water & Related Utilities  2014
# ALFAA.MX                          Industrial Conglomerates  2014
# ALI.LM                                      Food & Tobacco  2014
# ALPA4.SA                                Textiles & Apparel  2014
#
#                   capx  book_value_per_share         csho       deb_tot  \
# id
# ABEV3.SA -1.691000e+09              1.013250  15710000000  9.871000e+08
# AC.MX    -3.119000e+08              1.939020   1611000000  1.070000e+09
# AGR.BA   -3.360144e+05              0.285851     48000000  6.929635e+06
# AGU.SN   -6.054200e+07              0.192198    855100000  2.309000e+08
# AGUAa.SN -1.356000e+08              0.164602   6119000000  1.245000e+09
# ALFAA.MX -1.937000e+09              0.730240   5135000000  6.234000e+09
# ALI.LM   -1.133000e+08              0.819730    854600000  9.253000e+08
# ALPA4.SA -5.245691e+07              1.631650    460800000  1.935000e+08
#
#              ...             age  total_equity          ebit  total_liability  \
# id           ...
# ABEV3.SA     ...       12.150580  1.589000e+10  6.016000e+09     1.126000e+10
# AC.MX        ...        6.272416  3.124000e+09  7.315000e+08     2.324000e+09
# AGR.BA       ...       59.373030  1.372086e+07  4.457442e+06     1.425696e+07
# AGU.SN       ...       27.775500  1.643000e+08  2.735000e+07     4.171000e+08
# AGUAa.SN     ...       28.240930  1.007000e+09  3.419000e+08     1.642000e+09
# ALFAA.MX     ...       50.403830  3.756000e+09  1.172000e+09     1.204000e+10
# ALI.LM       ...       12.238190  7.005000e+08  1.902000e+08     1.591000e+09
# ALPA4.SA     ...      110.414800  7.519000e+08  1.307000e+08     6.221000e+08
#
#                revenue      size  country  inflation  tax_rate  population
# id
# ABEV3.SA  1.433000e+10  23.38575      NaN        NaN       NaN         NaN
# AC.MX     4.202000e+09  22.15887      NaN        NaN       NaN         NaN
# AGR.BA    3.141261e+07  17.26272      NaN        NaN       NaN         NaN
# AGU.SN    6.122000e+08  20.23258      NaN        NaN       NaN         NaN
# AGUAa.SN  7.268000e+08  20.40417      NaN        NaN       NaN         NaN
# ALFAA.MX  1.555000e+10  23.46714      NaN        NaN       NaN         NaN
# ALI.LM    2.109000e+09  21.46952      NaN        NaN       NaN         NaN
# ALPA4.SA  1.294000e+09  20.98069      NaN        NaN       NaN         NaN
#
# [8 rows x 29 columns]

# %% [markdown]
# #### Tercera forma de hacerlo MAL: Perdile que ocupe como eje de pegado en base a la columna "country"
#
# Bueno intento...pero NO. Lo que obtendremos al realizar esto será algo como esto.

# %%
merged_data_2014_countries_wrong3 =  pd.concat([merged_data_2014, merge_countries] , axis=1 ,join_axes=[merged_data_2014['country']] )
merged_data_2014_countries_wrong3.head(8)
# Out:
#           CompanyCommonName  country TRBCEconomicSectorName  \
# country
# Brazil                  NaN      NaN                    NaN
# Mexico                  NaN      NaN                    NaN
# Argentina               NaN      NaN                    NaN
# Chile                   NaN      NaN                    NaN
# Chile                   NaN      NaN                    NaN
# Mexico                  NaN      NaN                    NaN
# Peru                    NaN      NaN                    NaN
# Brazil                  NaN      NaN                    NaN
#
#           TRBCBusinessSectorName industry  time  capx  book_value_per_share  \
# country
# Brazil                       NaN      NaN   NaN   NaN                   NaN
# Mexico                       NaN      NaN   NaN   NaN                   NaN
# Argentina                    NaN      NaN   NaN   NaN                   NaN
# Chile                        NaN      NaN   NaN   NaN                   NaN
# Chile                        NaN      NaN   NaN   NaN                   NaN
# Mexico                       NaN      NaN   NaN   NaN                   NaN
# Peru                         NaN      NaN   NaN   NaN                   NaN
# Brazil                       NaN      NaN   NaN   NaN                   NaN
#
#            csho  deb_tot     ...      age  total_equity  ebit  \
# country                      ...
# Brazil      NaN      NaN     ...      NaN           NaN   NaN
# Mexico      NaN      NaN     ...      NaN           NaN   NaN
# Argentina   NaN      NaN     ...      NaN           NaN   NaN
# Chile       NaN      NaN     ...      NaN           NaN   NaN
# Chile       NaN      NaN     ...      NaN           NaN   NaN
# Mexico      NaN      NaN     ...      NaN           NaN   NaN
# Peru        NaN      NaN     ...      NaN           NaN   NaN
# Brazil      NaN      NaN     ...      NaN           NaN   NaN
#
#            total_liability  revenue  size  country  inflation  tax_rate  \
# country
# Brazil                 NaN      NaN   NaN      NaN        NaN       NaN
# Mexico                 NaN      NaN   NaN      NaN        NaN       NaN
# Argentina              NaN      NaN   NaN      NaN        NaN       NaN
# Chile                  NaN      NaN   NaN      NaN        NaN       NaN
# Chile                  NaN      NaN   NaN      NaN        NaN       NaN
# Mexico                 NaN      NaN   NaN      NaN        NaN       NaN
# Peru                   NaN      NaN   NaN      NaN        NaN       NaN
# Brazil                 NaN      NaN   NaN      NaN        NaN       NaN
#
#            population
# country
# Brazil            NaN
# Mexico            NaN
# Argentina         NaN
# Chile             NaN
# Chile             NaN
# Mexico            NaN
# Peru              NaN
# Brazil            NaN
#
# [8 rows x 29 columns]

# %% [markdown]
# Bueno, vemos que este último intento también salió pésimo... ¿Qué hemos aprendido de todo esto? Concat no nos servirá para lo que queremos hacer. Por ende recurriremos al próximo comando de esta sesión

# %% [markdown]
# # Solución?: [Merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html)!
#
# Este otro comando nos permite indicarle que realize el pegado basado en alguna columna común que tengan ambos DataFrame. La que en este caso corresponde a la columna "**country**". La sintaxis de este comando corresponde a:
#
# 1. DataFrames a ser pegados: En nuestro caso (**merged_data_2014**, **merge_countries**)
# 2. Columna común que comparten ambos DataFrame que servirá de "llave"
# 3. how: Corresponde al orden de las variables

# %%
merged_data_2014_countries = pd.merge(merged_data_2014, merge_countries, on='country')
merged_data_2014_countries.head(5)
# Out:
#                   CompanyCommonName country  TRBCEconomicSectorName  \
# 0                          Ambev SA  Brazil  Consumer Non-Cyclicals
# 1                     Alpargatas SA  Brazil      Consumer Cyclicals
# 2                         Baumer SA  Brazil              Healthcare
# 3  Bardella SA Industrias Mecanicas  Brazil             Industrials
# 4              BICICLETAS MONARK SA  Brazil      Consumer Cyclicals
#
#             TRBCBusinessSectorName  \
# 0                 Food & Beverages
# 1       Cyclical Consumer Products
# 2  Healthcare Services & Equipment
# 3                 Industrial Goods
# 4       Cyclical Consumer Products
#
#                                            industry  time          capx  \
# 0                                         Beverages  2014 -1.691000e+09
# 1                                Textiles & Apparel  2014 -5.245691e+07
# 2                   Healthcare Equipment & Supplies  2014 -1.658261e+06
# 3  Machinery, Tools, Heavy Vehicles, Trains & Ships  2014 -2.783967e+06
# 4                                  Leisure Products  2014 -2.860369e+04
#
#    book_value_per_share         csho      deb_tot     ...       debtcap  \
# 0              1.013250  15710000000  987100000.0     ...      0.058483
# 1              1.631650    460800000  193500000.0     ...      0.204641
# 2              2.834907      9800000    8060971.0     ...      0.224896
# 3             79.303020      1600000   62066616.0     ...      0.328479
# 4            148.955030       454750          0.0     ...      0.000000
#
#          age  total_equity          ebit  total_liability       revenue  \
# 0   12.15058  1.589000e+10  6.016000e+09     1.126000e+10  1.433000e+10
# 1  110.41480  7.519000e+08  1.307000e+08     6.221000e+08  1.294000e+09
# 2   65.31964  2.778208e+07  6.486263e+06     2.373767e+07  4.377004e+07
# 3  106.55440  1.269000e+08  4.010915e+06     1.704000e+08  1.803000e+08
# 4   69.34976  6.773730e+07  1.757621e+05     9.463681e+06  1.228754e+07
#
#        size  inflation  tax_rate  population
# 0  23.38575   0.052223  0.398399   204519000
# 1  20.98069   0.052223  0.398399   204519000
# 2  17.59446   0.052223  0.398399   204519000
# 3  19.00988   0.052223  0.398399   204519000
# 4  16.32410   0.052223  0.398399   204519000
#
# [5 rows x 28 columns]

# %% [markdown]
# ####¿Dónde se fue Perú?
#
# Si revisamos el DataFrame que recién creamos vemos que perú ha desaparecido de la base.

# %%
merged_data_2014_countries['country'].value_counts()
# Out:
# Brazil       62
# Chile        58
# Mexico       26
# Argentina    23
# Colombia      2
# Name: country, dtype: int64

# %% [markdown]
# #### Recuperemos a Perú!
#
# Qué ha pasado entonces? Lo que ha ocurrido es que hemos sido demasiado descuidados con un elemento clave del comando merge que es el atributo **HOW**. El cual nos indica la forma en la que realizaremos el pegado. En este caso este atributo tiene 4 opciones.
#
# 1. outer: Nos permite quedarnos con la intersección de ambos DataFrames. Conservando todos los valores que no tengan correspondencia en alguno de los DataFrame.
# 2. Inner: Genera un unión que intersecta los valores de ambos DataFrames. Es decir elimina cualquier valor no matcheado en alguno de los DataFrame. En este caso, Perú no aparece en la base **merge_countries**, por lo que se eliminará de la base. Esta es la opción por defecto de Pandas así que por Perú había desaparecido de la base.
# 3. left: Se queda sólo con los datos del lado izquierdo (primera base que se ingresa en los argumentos de **merge**)
# 4. right:  Se queda sólo con los datos del lado derecho (segunda base que se ingresa en los argumentos de **merge**)
#
# > Si no recuerdas bien que significa "intersección", "union", "unión por la derecha o izquiera", puedes revisar el siguiente [link](https://en.wikipedia.org/wiki/Venn_diagram)
#
# Por lo tanto... para recuperar a Perú podemos ocupar el siguiente comando

# %%
merged_data_2014_countries = pd.merge(merged_data_2014, merge_countries, on='country' , how = 'outer')
merged_data_2014_countries['country'].value_counts()
# Out:
# Brazil       62
# Chile        58
# Mexico       26
# Argentina    23
# Peru         20
# Colombia      2
# Name: country, dtype: int64

# %%
#Podemos ver que Perú se quedó en la base, pero efectivamente sin la información adicional de la base 'merge_country'
merged_data_2014_countries[merged_data_2014_countries['country']=='Peru' ].head(5)
# Out:
#                                CompanyCommonName country  \
# 169                                  Alicorp SAA    Peru
# 170               Corporacion Aceros Arequipa SA    Peru
# 171                            Austral Group SAA    Peru
# 172           Compania de Minas Buenaventura SAA    Peru
# 173  Central Azucarera Chucarapi Pampa Blanca SA    Peru
#
#      TRBCEconomicSectorName TRBCBusinessSectorName         industry  time  \
# 169  Consumer Non-Cyclicals       Food & Beverages   Food & Tobacco  2014
# 170         Basic Materials      Mineral Resources  Metals & Mining  2014
# 171  Consumer Non-Cyclicals       Food & Beverages   Food & Tobacco  2014
# 172         Basic Materials      Mineral Resources  Metals & Mining  2014
# 173  Consumer Non-Cyclicals       Food & Beverages   Food & Tobacco  2014
#
#             capx  book_value_per_share        csho       deb_tot     ...      \
# 169 -113300000.0              0.819730   854600000  9.253000e+08     ...
# 170  -18970460.0              0.508297  1117000000  3.374000e+08     ...
# 171  -23395099.0              0.677967   259000000  1.191000e+08     ...
# 172 -227600000.0             13.628182   254200000  4.463000e+08     ...
# 173          0.0              8.133921     2342500  1.725411e+05     ...
#
#       debtcap       age  total_equity         ebit  total_liability  \
# 169  0.569132  12.23819  7.005000e+08  190200000.0     1.591000e+09
# 170  0.372631  19.58932  5.680000e+08   60305807.0     4.847000e+08
# 171  0.404057  18.91855  1.756000e+08    6103726.1     1.675000e+08
# 172  0.114138  57.98494  3.464000e+09   61596000.0     1.208000e+09
# 173  0.008974  24.29295  1.905371e+07   -2942742.5     1.341490e+07
#
#           revenue      size  inflation  tax_rate  population
# 169  2.109000e+09  21.46952        NaN       NaN         NaN
# 170  8.067000e+08  20.50852        NaN       NaN         NaN
# 171  1.526000e+08  18.84310        NaN       NaN         NaN
# 172  1.176000e+09  20.88520        NaN       NaN         NaN
# 173  4.704599e+06  15.36405        NaN       NaN         NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Un Último Comentario.
# Algo muy importante que un alumno juicioso debería haber notado a esta altura, es que hemos perdido el **index** de nuestro DataFrame, lo que lo ha vuelto completamente inútil ya que ha perdido su "llave". (con lo que básicamente obtuvimos  una pizza sin queso...)
#
# **¿Cómo recuperarlo?**
#
# Bueno, volvamos un poco en el tiempo, hasta la línea.
#
#
# ```
# merge_firms.set_index('id', inplace=True , drop =True)
# ```
#
# En esta linea hicimos que la columna llamada 'id' desapareciera del DataFrame para formar parte del 'index'. Ahora, adivinen... drop =False. Con eso mantendremos un respaldo del index dentro del DataFrame.
# Ejecutemos esta versión paralela de nuestro código.

# %%
#Re-cargando merge_firms
merge_firms = pd.read_excel(excel_file, sheetname='merge_firms')
merge_firms=merge_firms.set_index('id', inplace=False ,drop= False) #Mantenemos columna id

#Re-cargando merge_firms_to_add
merge_firms_to_add = pd.read_excel(excel_file, sheetname='merge_firms_to_add')
merge_firms_to_add=merge_firms_to_add.set_index('id', inplace=False , drop =True) #Borramos columna id para que no esté duplicada

#Concat merge_firms y  merge_firms_to_add
merged_data_2014 = pd.concat([merge_firms, merge_firms_to_add], axis=1, join_axes=[merge_firms_to_add.index])

#Merge merged_data_2014 con merge_countries
merged_data_2014_countries = pd.merge(merged_data_2014, merge_countries, on='country' , how = 'outer')
merged_data_2014_countries[merged_data_2014_countries['country']=='Peru' ].head(5)
# Out:
#           id                            CompanyCommonName country  \
# 169   ALI.LM                                  Alicorp SAA    Peru
# 170   ARE.LM               Corporacion Aceros Arequipa SA    Peru
# 171   AUG.LM                            Austral Group SAA    Peru
# 172  BUEv.LM           Compania de Minas Buenaventura SAA    Peru
# 173   CHU.LM  Central Azucarera Chucarapi Pampa Blanca SA    Peru
#
#      TRBCEconomicSectorName TRBCBusinessSectorName         industry  time  \
# 169  Consumer Non-Cyclicals       Food & Beverages   Food & Tobacco  2014
# 170         Basic Materials      Mineral Resources  Metals & Mining  2014
# 171  Consumer Non-Cyclicals       Food & Beverages   Food & Tobacco  2014
# 172         Basic Materials      Mineral Resources  Metals & Mining  2014
# 173  Consumer Non-Cyclicals       Food & Beverages   Food & Tobacco  2014
#
#             capx  book_value_per_share        csho     ...       debtcap  \
# 169 -113300000.0              0.819730   854600000     ...      0.569132
# 170  -18970460.0              0.508297  1117000000     ...      0.372631
# 171  -23395099.0              0.677967   259000000     ...      0.404057
# 172 -227600000.0             13.628182   254200000     ...      0.114138
# 173          0.0              8.133921     2342500     ...      0.008974
#
#           age  total_equity         ebit  total_liability       revenue  \
# 169  12.23819  7.005000e+08  190200000.0     1.591000e+09  2.109000e+09
# 170  19.58932  5.680000e+08   60305807.0     4.847000e+08  8.067000e+08
# 171  18.91855  1.756000e+08    6103726.1     1.675000e+08  1.526000e+08
# 172  57.98494  3.464000e+09   61596000.0     1.208000e+09  1.176000e+09
# 173  24.29295  1.905371e+07   -2942742.5     1.341490e+07  4.704599e+06
#
#          size  inflation  tax_rate  population
# 169  21.46952        NaN       NaN         NaN
# 170  20.50852        NaN       NaN         NaN
# 171  18.84310        NaN       NaN         NaN
# 172  20.88520        NaN       NaN         NaN
# 173  15.36405        NaN       NaN         NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# Ahora sólo nos falta repetir el proceso para asignar la columna 'id' como index al DataFrame recién creado.

# %%
merged_data_2014_countries= merged_data_2014_countries.set_index('id', inplace=False ,drop= False)
merged_data_2014_countries.head(5)
# Out:
#                 id                 CompanyCommonName country  \
# id
# ABEV3.SA  ABEV3.SA                          Ambev SA  Brazil
# ALPA4.SA  ALPA4.SA                     Alpargatas SA  Brazil
# BALM4.SA  BALM4.SA                         Baumer SA  Brazil
# BDLL4.SA  BDLL4.SA  Bardella SA Industrias Mecanicas  Brazil
# BMKS3.SA  BMKS3.SA              BICICLETAS MONARK SA  Brazil
#
#           TRBCEconomicSectorName           TRBCBusinessSectorName  \
# id
# ABEV3.SA  Consumer Non-Cyclicals                 Food & Beverages
# ALPA4.SA      Consumer Cyclicals       Cyclical Consumer Products
# BALM4.SA              Healthcare  Healthcare Services & Equipment
# BDLL4.SA             Industrials                 Industrial Goods
# BMKS3.SA      Consumer Cyclicals       Cyclical Consumer Products
#
#                                                   industry  time  \
# id
# ABEV3.SA                                         Beverages  2014
# ALPA4.SA                                Textiles & Apparel  2014
# BALM4.SA                   Healthcare Equipment & Supplies  2014
# BDLL4.SA  Machinery, Tools, Heavy Vehicles, Trains & Ships  2014
# BMKS3.SA                                  Leisure Products  2014
#
#                   capx  book_value_per_share         csho     ...       \
# id                                                            ...
# ABEV3.SA -1.691000e+09              1.013250  15710000000     ...
# ALPA4.SA -5.245691e+07              1.631650    460800000     ...
# BALM4.SA -1.658261e+06              2.834907      9800000     ...
# BDLL4.SA -2.783967e+06             79.303020      1600000     ...
# BMKS3.SA -2.860369e+04            148.955030       454750     ...
#
#            debtcap        age  total_equity          ebit  total_liability  \
# id
# ABEV3.SA  0.058483   12.15058  1.589000e+10  6.016000e+09     1.126000e+10
# ALPA4.SA  0.204641  110.41480  7.519000e+08  1.307000e+08     6.221000e+08
# BALM4.SA  0.224896   65.31964  2.778208e+07  6.486263e+06     2.373767e+07
# BDLL4.SA  0.328479  106.55440  1.269000e+08  4.010915e+06     1.704000e+08
# BMKS3.SA  0.000000   69.34976  6.773730e+07  1.757621e+05     9.463681e+06
#
#                revenue      size  inflation  tax_rate   population
# id
# ABEV3.SA  1.433000e+10  23.38575   0.052223  0.398399  204519000.0
# ALPA4.SA  1.294000e+09  20.98069   0.052223  0.398399  204519000.0
# BALM4.SA  4.377004e+07  17.59446   0.052223  0.398399  204519000.0
# BDLL4.SA  1.803000e+08  19.00988   0.052223  0.398399  204519000.0
# BMKS3.SA  1.228754e+07  16.32410   0.052223  0.398399  204519000.0
#
# [5 rows x 29 columns]

# %% [markdown]
# Con lo que hemos pegado apropiadamente la información a nivel país, sin perder la información del identificador de cada empresa (**id**).

# %% [markdown]
# #GroupBy
#
# Esto nos permitirá a acceder a niveles de agregación jerarquizados. Por ejemplo, en nuestra base de datos tenemos los siguientes niveles de agregación desde el más "micro" hasta el más "macro".
# 1. **Index** (columna **id** en un principio): Información a nivel de **firma**.
# 2. **TRBCEconomicSectorName**	: Información a nivel de **Sector Económico **.
# 3. **industry**: Información a nivel de **Industria**.
# 4. **country**: Información a nivel de **país**.
#
# Por lo tanto, una serie de preguntas secillas que pueden ser respondida haciendo uso de este comando podrían ser:

# %%
#Promedio de activos totales(at) por industria.
merged_data_2014_countries.groupby('industry')['at'].mean()
# Out:
# industry
# Aerospace & Defense                                 5.389350e+09
# Automobiles & Auto Parts                            2.367000e+09
# Beverages                                           9.132333e+09
# Chemicals                                           3.273703e+09
# Communications & Networking                         2.602000e+08
# Computers, Phones & Household Electronics           2.379000e+08
# Construction & Engineering                          2.418420e+09
# Construction Materials                              7.482080e+09
# Containers & Packaging                              8.616349e+07
# Diversified Retail                                  8.535240e+09
# Electric Utilities & IPPs                           7.458549e+09
# Food & Drug Retailing                               4.408786e+09
# Food & Tobacco                                      1.138845e+09
# Freight & Logistics Services                        9.441833e+08
# Healthcare Equipment & Supplies                     5.151976e+07
# Healthcare Providers & Services                     6.405333e+08
# Homebuilding & Construction Supplies                2.132212e+09
# Hotels & Entertainment Services                     6.970593e+07
# Household Goods                                     1.062197e+09
# Industrial Conglomerates                            1.304262e+10
# Leisure Products                                    6.367194e+07
# Machinery, Tools, Heavy Vehicles, Trains & Ships    6.488757e+08
# Media & Publishing                                  6.186264e+09
# Metals & Mining                                     1.122813e+10
# Natural Gas Utilities                               1.568250e+09
# Oil & Gas                                           5.263600e+10
# Paper & Forest Products                             8.441217e+09
# Passenger Transportation Services                   2.048000e+10
# Personal & Household Products & Services            2.841000e+08
# Pharmaceuticals                                     1.648150e+07
# Renewable Energy                                    4.504485e+07
# Specialty Retailers                                 2.236000e+09
# Telecommunications Services                         2.057100e+10
# Textiles & Apparel                                  4.590573e+08
# Transport Infrastructure                            2.126540e+09
# Water & Related Utilities                           5.637000e+09
# Name: at, dtype: float64

# %%
#Mediana de la edad de las firmas (age) por país
merged_data_2014_countries.groupby('country')['age'].median()
# Out:
# country
# Argentina    59.373030
# Brazil       60.562630
# Chile        50.599590
# Colombia     37.478440
# Mexico       30.837780
# Peru         24.365505
# Name: age, dtype: float64

# %%
#Promedio de la deuda total(total_liability) por país e industria
merged_data_2014_countries.groupby(['country', 'industry'])['total_liability'].mean()
# Out:
# country    industry
# Argentina  Chemicals                                           2.092844e+08
#            Computers, Phones & Household Electronics           2.752000e+08
#            Electric Utilities & IPPs                           2.782333e+08
#            Food & Drug Retailing                               1.330800e+09
#            Food & Tobacco                                      2.247814e+08
#            Machinery, Tools, Heavy Vehicles, Trains & Ships    1.425696e+07
#            Metals & Mining                                     5.555500e+08
#            Natural Gas Utilities                               3.531000e+08
#            Oil & Gas                                           5.492767e+09
#            Paper & Forest Products                             1.273490e+07
#            Pharmaceuticals                                     8.984983e+06
#            Telecommunications Services                         1.393000e+09
#            Textiles & Apparel                                  7.062351e+07
# Brazil     Aerospace & Defense                                 3.496550e+09
#            Automobiles & Auto Parts                            1.846000e+09
#            Beverages                                           1.126000e+10
#            Chemicals                                           8.361250e+09
#            Computers, Phones & Household Electronics           6.788032e+07
#            Construction & Engineering                          1.397060e+09
#            Diversified Retail                                  2.892184e+09
#            Electric Utilities & IPPs                           9.518920e+09
#            Food & Drug Retailing                               6.636750e+09
#            Food & Tobacco                                      3.067000e+08
#            Freight & Logistics Services                        1.060000e+09
#            Healthcare Equipment & Supplies                     2.373767e+07
#            Homebuilding & Construction Supplies                1.932514e+08
#            Household Goods                                     1.627000e+09
#            Industrial Conglomerates                            5.808431e+07
#            Leisure Products                                    7.958609e+07
#            Machinery, Tools, Heavy Vehicles, Trains & Ships    4.274144e+08
#                                                                    ...
# Chile      Renewable Energy                                    2.411862e+07
#            Telecommunications Services                         3.036333e+09
#            Transport Infrastructure                            1.378500e+08
#            Water & Related Utilities                           1.642000e+09
# Colombia   Electric Utilities & IPPs                           7.844000e+09
#            Food & Drug Retailing                               1.505000e+09
# Mexico     Beverages                                           7.835667e+09
#            Chemicals                                           1.047950e+09
#            Construction & Engineering                          6.924000e+09
#            Construction Materials                              2.603000e+10
#            Diversified Retail                                  6.680000e+09
#            Food & Drug Retailing                               2.328000e+09
#            Food & Tobacco                                      4.303128e+09
#            Freight & Logistics Services                        8.380000e+08
#            Homebuilding & Construction Supplies                3.148750e+09
#            Industrial Conglomerates                            5.255667e+09
#            Media & Publishing                                  4.160881e+09
#            Metals & Mining                                     5.109900e+09
#            Telecommunications Services                         7.420000e+10
#            Transport Infrastructure                            4.626500e+08
# Peru       Construction & Engineering                          1.692000e+09
#            Construction Materials                              4.191000e+08
#            Containers & Packaging                              2.967774e+07
#            Diversified Retail                                  3.265000e+08
#            Electric Utilities & IPPs                           6.379000e+08
#            Food & Tobacco                                      3.895366e+08
#            Homebuilding & Construction Supplies                3.892000e+08
#            Machinery, Tools, Heavy Vehicles, Trains & Ships    5.023517e+08
#            Metals & Mining                                     9.574040e+08
#            Telecommunications Services                         1.973000e+09
# Name: total_liability, Length: 89, dtype: float64

# %%
merged_data_2014_countries.groupby(['country', 'industry'])['total_liability'].mean().reset_index()
# Out:
#       country                                          industry  \
# 0   Argentina                                         Chemicals
# 1   Argentina         Computers, Phones & Household Electronics
# 2   Argentina                         Electric Utilities & IPPs
# 3   Argentina                             Food & Drug Retailing
# 4   Argentina                                    Food & Tobacco
# 5   Argentina  Machinery, Tools, Heavy Vehicles, Trains & Ships
# 6   Argentina                                   Metals & Mining
# 7   Argentina                             Natural Gas Utilities
# 8   Argentina                                         Oil & Gas
# 9   Argentina                           Paper & Forest Products
# 10  Argentina                                   Pharmaceuticals
# 11  Argentina                       Telecommunications Services
# 12  Argentina                                Textiles & Apparel
# 13     Brazil                               Aerospace & Defense
# 14     Brazil                          Automobiles & Auto Parts
# 15     Brazil                                         Beverages
# 16     Brazil                                         Chemicals
# 17     Brazil         Computers, Phones & Household Electronics
# 18     Brazil                        Construction & Engineering
# 19     Brazil                                Diversified Retail
# 20     Brazil                         Electric Utilities & IPPs
# 21     Brazil                             Food & Drug Retailing
# 22     Brazil                                    Food & Tobacco
# 23     Brazil                      Freight & Logistics Services
# 24     Brazil                   Healthcare Equipment & Supplies
# 25     Brazil              Homebuilding & Construction Supplies
# 26     Brazil                                   Household Goods
# 27     Brazil                          Industrial Conglomerates
# 28     Brazil                                  Leisure Products
# 29     Brazil  Machinery, Tools, Heavy Vehicles, Trains & Ships
# ..        ...                                               ...
# 59      Chile                                  Renewable Energy
# 60      Chile                       Telecommunications Services
# 61      Chile                          Transport Infrastructure
# 62      Chile                         Water & Related Utilities
# 63   Colombia                         Electric Utilities & IPPs
# 64   Colombia                             Food & Drug Retailing
# 65     Mexico                                         Beverages
# 66     Mexico                                         Chemicals
# 67     Mexico                        Construction & Engineering
# 68     Mexico                            Construction Materials
# 69     Mexico                                Diversified Retail
# 70     Mexico                             Food & Drug Retailing
# 71     Mexico                                    Food & Tobacco
# 72     Mexico                      Freight & Logistics Services
# 73     Mexico              Homebuilding & Construction Supplies
# 74     Mexico                          Industrial Conglomerates
# 75     Mexico                                Media & Publishing
# 76     Mexico                                   Metals & Mining
# 77     Mexico                       Telecommunications Services
# 78     Mexico                          Transport Infrastructure
# 79       Peru                        Construction & Engineering
# 80       Peru                            Construction Materials
# 81       Peru                            Containers & Packaging
# 82       Peru                                Diversified Retail
# 83       Peru                         Electric Utilities & IPPs
# 84       Peru                                    Food & Tobacco
# 85       Peru              Homebuilding & Construction Supplies
# 86       Peru  Machinery, Tools, Heavy Vehicles, Trains & Ships
# 87       Peru                                   Metals & Mining
# 88       Peru                       Telecommunications Services
#
#     total_liability
# 0      2.092844e+08
# 1      2.752000e+08
# 2      2.782333e+08
# 3      1.330800e+09
# 4      2.247814e+08
# 5      1.425696e+07
# 6      5.555500e+08
# 7      3.531000e+08
# 8      5.492767e+09
# 9      1.273490e+07
# 10     8.984983e+06
# 11     1.393000e+09
# 12     7.062351e+07
# 13     3.496550e+09
# 14     1.846000e+09
# 15     1.126000e+10
# 16     8.361250e+09
# 17     6.788032e+07
# 18     1.397060e+09
# 19     2.892184e+09
# 20     9.518920e+09
# 21     6.636750e+09
# 22     3.067000e+08
# 23     1.060000e+09
# 24     2.373767e+07
# 25     1.932514e+08
# 26     1.627000e+09
# 27     5.808431e+07
# 28     7.958609e+07
# 29     4.274144e+08
# ..              ...
# 59     2.411862e+07
# 60     3.036333e+09
# 61     1.378500e+08
# 62     1.642000e+09
# 63     7.844000e+09
# 64     1.505000e+09
# 65     7.835667e+09
# 66     1.047950e+09
# 67     6.924000e+09
# 68     2.603000e+10
# 69     6.680000e+09
# 70     2.328000e+09
# 71     4.303128e+09
# 72     8.380000e+08
# 73     3.148750e+09
# 74     5.255667e+09
# 75     4.160881e+09
# 76     5.109900e+09
# 77     7.420000e+10
# 78     4.626500e+08
# 79     1.692000e+09
# 80     4.191000e+08
# 81     2.967774e+07
# 82     3.265000e+08
# 83     6.379000e+08
# 84     3.895366e+08
# 85     3.892000e+08
# 86     5.023517e+08
# 87     9.574040e+08
# 88     1.973000e+09
#
# [89 rows x 3 columns]
